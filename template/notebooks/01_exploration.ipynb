# %% [markdown]
# # 01. Exploratory Data Analysis
#
# Initialize analytic exploration notebook using Polars and DuckDB.

# %%
import duckdb
import polars as pl

print("DuckDB version:", duckdb.__version__)
print("Polars version:", pl.__version__)
